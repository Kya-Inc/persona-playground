# %%
# !git clone https://github.com/Kya-Inc/persona-playground.git personas
# Out:
# Cloning into 'personas'...
# remote: Enumerating objects: 273, done.
# remote: Counting objects: 100% (273/273), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 273 (delta 132), reused 231 (delta 90), pack-reused 0
# Receiving objects: 100% (273/273), 18.56 MiB | 14.20 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
# mount Google Drive and edit path to copy .env with sensitive env variables
# !cp drive/MyDrive/colab_env/.env personas/.env

# %%
# !pip install -r personas/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 82.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 91.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 67.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 12.6 MB/s eta 0:00:00
# ...

# %%
# %cd personas/data
# Out:
# /content/personas/data

# %%
# !PYTHONPATH=../ python homer_simpson.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")

# %%
# !PYTHONPATH=../ python nedward_flanders.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  1520
# thoughts 340
# total records:  1860
# merged lines:  197
# total lines:  2057
# WARNING:root:Batch upload failed 1 times. Retrying...
# WARNING:root:Batch upload failed 2 times. Retrying...
# WARNING:root:Batch upload failed 3 times. Retrying...
# Traceback (most recent call last):
#   File "/content/personas/data/nedward_flanders.py", line 64, in <module>
#     embed_character_dialogue(
#   File "/content/personas/embed.py", line 154, in embed_character_dialogue
#     qdrant.upload_records(collection_name="cues", records=cue_records)
#   File "/usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_client.py", line 1509, in upload_records
#     return self._client.upload_records(
# ...

# %%
# !PYTHONPATH=../ python montgomery_burns.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  2055
# thoughts 543
# total records:  2598
# merged lines:  489
# total lines:  3087

# %%
# !PYTHONPATH=../ python krusty_the_clown.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# ...
# cue/response pairs:  1108
# thoughts 292
# total records:  1400
# merged lines:  304
# total lines:  1704

# %%
# !PYTHONPATH=../ python bart_simpson.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  9896
# thoughts 2042
# total records:  11938
# merged lines:  1075
# total lines:  13013
# WARNING:root:Batch upload failed 1 times. Retrying...
# WARNING:root:Batch upload failed 2 times. Retrying...
# WARNING:root:Batch upload failed 3 times. Retrying...
# Traceback (most recent call last):
#   File "/content/personas/data/bart_simpson.py", line 60, in <module>
#     embed_character_dialogue(
#   File "/content/personas/embed.py", line 154, in embed_character_dialogue
#     qdrant.upload_records(collection_name="cues", records=cue_records)
#   File "/usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_client.py", line 1509, in upload_records
#     return self._client.upload_records(
# ...

# %%
# !PYTHONPATH=../ python michael_scott.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  10050
# thoughts 0
# total records:  10050
# merged lines:  723
# total lines:  10773

# %%
# !PYTHONPATH=../ python dwight_schrute.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  6467
# thoughts 0
# total records:  6467
# merged lines:  285
# total lines:  6752

# %%
# !PYTHONPATH=../ python jim_halpert.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  6036
# thoughts 0
# total records:  6036
# merged lines:  186
# total lines:  6222

# %%
# !PYTHONPATH=../ python pam_beesly.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  4812
# thoughts 0
# total records:  4812
# merged lines:  161
# total lines:  4973

# %%
# !PYTHONPATH=../ python kevin_malone.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  1506
# thoughts 0
# total records:  1506
# merged lines:  29
# total lines:  1535

# %%
# !PYTHONPATH=../ python stanley_hudson.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  657
# thoughts 0
# total records:  657
# merged lines:  14
# total lines:  671

# %%
# !PYTHONPATH=../ python creed_bratton.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  374
# thoughts 0
# total records:  374
# merged lines:  20
# total lines:  394

# %%
# !PYTHONPATH=../ python andy_bernard.py
# Out:
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_remote.py:115: UserWarning: Api key is used with unsecure connection.
#   warnings.warn("Api key is used with unsecure connection.")
# cue/response pairs:  3554
# thoughts 0
# total records:  3554
# merged lines:  144
# total lines:  3698
